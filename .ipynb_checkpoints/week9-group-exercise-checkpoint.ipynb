# %% [markdown]
# ## Week 9 Exercise
# Made by: Grieving Banana
#
#
# ### Creating the data files: kennels_and_dogs.txt and registrations.txt

# %%
import random


names = ["BELLA","MOLLY", "LUNA","MILLE","CHARLIE","BALDER","MAX","BUSTER"]
breed = ["Labrador Retriever", "German Shepherd", "Golden Retriever", "French Bulldog", "Bulldog", "Beagle", "Poodle", "Rottweiler", "German Shorthaired Pointer", "Yorkshire Terrier"]

kennels = ["Kennel Juni's", "Dansk Kennel Klub", "Kennel Vestegnen", "Nanner's Hundecenter"]

def create_list(number):
    dogs = []
    
    #adding the kennels as the first 4 elements
    for name in kennels:
        kennel = {"name": name}
        dogs.append(kennel)
    
    #adding the dogs
    for i in range(number):
        dog = {"name": random.choice(names), "breed": random.choice(breed)}
        dogs.append(dog)
    
    return dogs

dogs = create_list(100)
print(dogs)
# Out:
# [{'name': "Kennel Juni's"}, {'name': 'Dansk Kennel Klub'}, {'name': 'Kennel Vestegnen'}, {'name': "Nanner's Hundecenter"}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'MOLLY', 'breed': 'French Bulldog'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'MOLLY', 'breed': 'Golden Retriever'}, {'name': 'MOLLY', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'German Shepherd'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'LUNA', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'Golden Retriever'}, {'name': 'BUSTER', 'breed': 'Labrador Retriever'}, {'name': 'CHARLIE', 'breed': 'French Bulldog'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'LUNA', 'breed': 'German Shepherd'}, {'name': 'MAX', 'breed': 'German Shepherd'}, {'name': 'BELLA', 'breed': 'Golden Retriever'}, {'name': 'CHARLIE', 'breed': 'Golden Retriever'}, {'name': 'CHARLIE', 'breed': 'Beagle'}, {'name': 'MAX', 'breed': 'Labrador Retriever'}, {'name': 'LUNA', 'breed': 'Bulldog'}, {'name': 'MAX', 'breed': 'German Shepherd'}, {'name': 'BALDER', 'breed': 'Labrador Retriever'}, {'name': 'MAX', 'breed': 'Poodle'}, {'name': 'BELLA', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'Labrador Retriever'}, {'name': 'LUNA', 'breed': 'German Shepherd'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'MOLLY', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'German Shorthaired Pointer'}, {'name': 'BALDER', 'breed': 'German Shepherd'}, {'name': 'MAX', 'breed': 'Labrador Retriever'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'Golden Retriever'}, {'name': 'LUNA', 'breed': 'Golden Retriever'}, {'name': 'MILLE', 'breed': 'Rottweiler'}, {'name': 'MOLLY', 'breed': 'Labrador Retriever'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'BELLA', 'breed': 'Labrador Retriever'}, {'name': 'BALDER', 'breed': 'German Shorthaired Pointer'}, {'name': 'BUSTER', 'breed': 'Yorkshire Terrier'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'BALDER', 'breed': 'Bulldog'}, {'name': 'MILLE', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'BUSTER', 'breed': 'Beagle'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'Yorkshire Terrier'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'LUNA', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'Rottweiler'}, {'name': 'MOLLY', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'BALDER', 'breed': 'Beagle'}, {'name': 'BALDER', 'breed': 'French Bulldog'}, {'name': 'MILLE', 'breed': 'German Shorthaired Pointer'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'LUNA', 'breed': 'Labrador Retriever'}, {'name': 'BUSTER', 'breed': 'Rottweiler'}, {'name': 'CHARLIE', 'breed': 'French Bulldog'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'MAX', 'breed': 'Labrador Retriever'}, {'name': 'BALDER', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'Labrador Retriever'}, {'name': 'MOLLY', 'breed': 'Golden Retriever'}, {'name': 'CHARLIE', 'breed': 'German Shorthaired Pointer'}, {'name': 'CHARLIE', 'breed': 'German Shepherd'}, {'name': 'BELLA', 'breed': 'Golden Retriever'}, {'name': 'MAX', 'breed': 'German Shepherd'}, {'name': 'BALDER', 'breed': 'Poodle'}, {'name': 'BUSTER', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Beagle'}, {'name': 'LUNA', 'breed': 'Beagle'}, {'name': 'LUNA', 'breed': 'German Shorthaired Pointer'}, {'name': 'CHARLIE', 'breed': 'Labrador Retriever'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'LUNA', 'breed': 'Poodle'}, {'name': 'BALDER', 'breed': 'Yorkshire Terrier'}, {'name': 'BALDER', 'breed': 'Rottweiler'}, {'name': 'BALDER', 'breed': 'Labrador Retriever'}, {'name': 'MAX', 'breed': 'Golden ...

# %%
kennel_numbers = []
dog_numbers = []

#Generating a list with ID's from 4-103(the dogs) and a list of random selection of the kennels
for i in range(4,104):
    no_kennel = random.randint(0, 3)
    kennel_numbers.append(no_kennel)
    dog_numbers.append(i)
    
registrations = list(zip(kennel_numbers, dog_numbers)) 
print(registrations)
# Out:
# [(0, 4), (1, 5), (2, 6), (1, 7), (0, 8), (1, 9), (1, 10), (1, 11), (1, 12), (1, 13), (3, 14), (3, 15), (2, 16), (0, 17), (3, 18), (2, 19), (2, 20), (3, 21), (1, 22), (1, 23), (0, 24), (0, 25), (2, 26), (2, 27), (0, 28), (0, 29), (1, 30), (2, 31), (0, 32), (3, 33), (1, 34), (0, 35), (0, 36), (0, 37), (3, 38), (1, 39), (2, 40), (3, 41), (1, 42), (0, 43), (3, 44), (1, 45), (2, 46), (2, 47), (0, 48), (2, 49), (2, 50), (3, 51), (2, 52), (0, 53), (3, 54), (1, 55), (2, 56), (2, 57), (1, 58), (3, 59), (2, 60), (1, 61), (2, 62), (3, 63), (2, 64), (3, 65), (2, 66), (0, 67), (3, 68), (3, 69), (1, 70), (1, 71), (3, 72), (3, 73), (3, 74), (3, 75), (1, 76), (0, 77), (2, 78), (3, 79), (0, 80), (0, 81), (2, 82), (2, 83), (0, 84), (2, 85), (0, 86), (0, 87), (0, 88), (0, 89), (1, 90), (0, 91), (0, 92), (2, 93), (3, 94), (1, 95), (0, 96), (2, 97), (2, 98), (1, 99), (2, 100), (1, 101), (3, 102), (3, 103)]

# %%
with open("registrations.txt","w") as file:
        file.write(str(registrations))

with open("kennels_and_dogs.txt","w") as file:
          file.write(str(dogs))

# %% [markdown]
# ### Exercise 1 - Graphs
#
# A. Read the list of dictionaries of dogs and kennels and the list of registrations from the textfiles: kennels_and_dogs.txt and registrations.txt
#
# Hint: import ast

# %%
import ast

with open('kennels_and_dogs.txt') as f:
    kennels_and_dogs = ast.literal_eval(f.read())

with open('registrations.txt') as f:
    registrations = ast.literal_eval(f.read())

# %%
print (kennels_and_dogs[:5])
# Out:
# [{'name': "Kennel Juni's"}, {'name': 'Dansk Kennel Klub'}, {'name': 'Kennel Vestegnen'}, {'name': "Nanner's Hundecenter"}, {'name': 'MILLE', 'breed': 'Bulldog'}]

# %% [markdown]
# B. Make a graph from the two lists and draw it
#
# Hint: install pygraphviz (with pip or conda)

# %%
from networkx.drawing.nx_agraph import graphviz_layout, write_dot
import matplotlib.pyplot as plt
import pygraphviz
import networkx as nx

def create_graph():
    graph = nx.DiGraph() 
    graph.clear()
    
    for idx, info in enumerate(kennels_and_dogs):
        graph.add_node(idx, node=info)
    
    graph.add_edges_from(registrations)

    return graph

def draw_graph(graph):
    nx.draw(graph, pos=graphviz_layout(graph),
            node_size=30, width=.05, cmap=plt.cm.Blues, 
            with_labels=True, node_color=range(len(graph)))

    
graph = create_graph()
print(nx.info(graph))
draw_graph(graph)
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 104
# Number of edges: 100
# Average in degree:   0.9615
# Average out degree:   0.9615

# %% [markdown]
# ## Exercise 2
#
# A. Which kennel has the most dogs registered?

# %%
import numpy as np

node_array = np.array([graph.degree(n) for n in graph.nodes()])
max = node_array.max()
max_idx = np.argmax(node_array)
print('Number of dogs: ' + str(max))
print('Kennel index: ' + str(max_idx))

print('The kennel with the most dogs is: ' + graph.nodes[max_idx]['node']['name'])
# Out:
# Number of dogs: 27
# Kennel index: 2
# The kennel with the most dogs is: Kennel Vestegnen

# %% [markdown]
# B. Get a list of all the dogs registered at this kennel

# %%
dog_edges = graph.edges(max_idx)

result = []

for edge in dog_edges:
    result.append(graph.nodes[edge[1]]['node'])

print(result)
# Out:
# [{'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'LUNA', 'breed': 'German Shepherd'}, {'name': 'CHARLIE', 'breed': 'Golden Retriever'}, {'name': 'CHARLIE', 'breed': 'Beagle'}, {'name': 'BELLA', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'Beagle'}, {'name': 'MOLLY', 'breed': 'Beagle'}, {'name': 'CHARLIE', 'breed': 'Poodle'}, {'name': 'MILLE', 'breed': 'German Shepherd'}, {'name': 'LUNA', 'breed': 'French Bulldog'}, {'name': 'MAX', 'breed': 'Yorkshire Terrier'}, {'name': 'MILLE', 'breed': 'Bulldog'}, {'name': 'BUSTER', 'breed': 'Yorkshire Terrier'}, {'name': 'MOLLY', 'breed': 'Poodle'}, {'name': 'MAX', 'breed': 'Beagle'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'BALDER', 'breed': 'French Bulldog'}, {'name': 'CHARLIE', 'breed': 'Yorkshire Terrier'}, {'name': 'BUSTER', 'breed': 'Rottweiler'}, {'name': 'BUSTER', 'breed': 'Bulldog'}, {'name': 'CHARLIE', 'breed': 'Labrador Retriever'}, {'name': 'BELLA', 'breed': 'Rottweiler'}, {'name': 'BALDER', 'breed': 'Yorkshire Terrier'}, {'name': 'LUNA', 'breed': 'Labrador Retriever'}, {'name': 'MILLE', 'breed': 'French Bulldog'}, {'name': 'MILLE', 'breed': 'Golden Retriever'}, {'name': 'MILLE', 'breed': 'Bulldog'}]

# %% [markdown]
# # 3. exercise
#
# first make the result into a pandas dataframe
#
# Make a function and use selenium to find the breed and prints the description.
# Go in https://www.petfinder.com/dog-breeds/ -> enter a breed from the list -> and click
#
# then call the function with random breeds from the dataframe to test your function

# %%
#import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

names= []
breeds = []

for dog in result:
    names.append(dog["name"])
    breeds.append(dog["breed"])

print (breeds)

def get_info(breed):
    browser = webdriver.Chrome("chromedriver.exe")
    browser.get('https://www.petfinder.com/dog-breeds/')
    
    browser.find_element_by_xpath("/html/body/pf-app/div[3]/div/div/div[1]/div/div[1]/div/div/div[3]/div[1]/input").send_keys(breed)
    time.sleep(4)
    browser.find_element_by_link_text(breed).click()

    text = browser.find_element_by_xpath('/html/body/pf-app/div[3]/div/div/div[1]/div/div[1]/div/div[1]/div[3]/div[2]/div[1]/p')

    return text.text


print(get_info(breeds[random.randint(0,10)]))
# Out:
# ['Bulldog', 'German Shepherd', 'Golden Retriever', 'Beagle', 'Yorkshire Terrier', 'Beagle', 'Beagle', 'Poodle', 'German Shepherd', 'French Bulldog', 'Yorkshire Terrier', 'Bulldog', 'Yorkshire Terrier', 'Poodle', 'Beagle', 'Yorkshire Terrier', 'French Bulldog', 'Yorkshire Terrier', 'Rottweiler', 'Bulldog', 'Labrador Retriever', 'Rottweiler', 'Yorkshire Terrier', 'Labrador Retriever', 'French Bulldog', 'Golden Retriever', 'Bulldog']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chromedriver.exe': 'chromedriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-a0c095368bc6> in <module>
#      26
#      27
# ---> 28 print(get_info(breeds[random.randint(0,10)]))
#      29
#
# <ipython-input-13-a0c095368bc6> in get_info(breed)
#      14
#      15 def get_info(breed):
# ---> 16     browser = webdriver.Chrome("chromedriver.exe")
#      17     browser.get('https://www.petfinder.com/dog-breeds/')
#      18
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home
